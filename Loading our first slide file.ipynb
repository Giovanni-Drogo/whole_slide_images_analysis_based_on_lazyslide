# %%
from wsidata import open_wsi

# 直接使用本地下载的文件
slide_path = "./GTEX-1117F-0526.svs"

# 现在打开幻灯片
wsi = open_wsi(slide_path)

# 检查 wsi 对象
print(wsi)
# Out:
# /root/miniconda3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# WSI: GTEX-1117F-0526.svs
# Reader: openslide
# Dimensions: 19958×19919 (h×w), 3 Pyramids
# Pixel physical size: 0.4942 MPP
# SpatialData object, with associated Zarr store: /root/lazyslide/GTEX-1117F-0526.zarr
# └── Images
#       └── 'wsi_thumbnail': DataArray[cyx] (3, 1996, 1992)
# with coordinate systems:
#     ▸ 'global', with elements:
#         wsi_thumbnail (Images)
# /root/miniconda3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)

# %%
import lazyslide as zs

zs.pl.tissue(wsi)

# %%
wsi.fetch.pyramids()
# Out:
#        height  width  downsample
# level
# 0       19958  19919    1.000000
# 1        4989   4979    4.000502
# 2        2494   2489    8.002609

# %%
wsi.properties
# Out:
# SlideProperties(shape=[19958, 19919], n_level=3, level_shape=[[19958, 19919], [4989, 4979], [2494, 2489]], level_downsample=[1.0, 4.000501706284455, 8.002609074152414], mpp=0.4942, magnification=20.0, bounds=[0, 0, 19919, 19958])

# %%
wsi.write()
# Out:
# INFO     The Zarr backing store has been changed from None the new file path: GTEX-1117F-0526.zarr

# %%
zs.pp.find_tissues(wsi)

# %%
zs.pl.tissue(wsi)

# %%
wsi
# Out:
# WSI: GTEX-1117F-0526.svs
# Reader: openslide
# Dimensions: 19958×19919 (h×w), 3 Pyramids
# Pixel physical size: 0.4942 MPP
# SpatialData object, with associated Zarr store: /root/lazyslide/GTEX-1117F-0526.zarr
# └── Images
#       └── 'wsi_thumbnail': DataArray[cyx] (3, 1996, 1992)
# with coordinate systems:
#     ▸ 'global', with elements:
#         wsi_thumbnail (Images)

# %%
zs.pl.tissue(wsi, tissue_id=0)
